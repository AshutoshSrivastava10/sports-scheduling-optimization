# %%
# !pip install gurobipy
from gurobipy import *
# Out:
# Collecting gurobipy
#   Downloading gurobipy-13.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (16 kB)
# Downloading gurobipy-13.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (14.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 34.8 MB/s eta 0:00:00
# Installing collected packages: gurobipy
# Successfully installed gurobipy-13.0.0

# %%
teams = ["CAN", "ICE", "SWE", "RUS", "DEN", "JAP", "ANT", "AUS", "CHI", "ARG", "TAH", "FIJ"]
north = ["CAN", "ICE", "SWE", "RUS", "DEN", "JAP"]
south = ["ANT", "AUS", "CHI", "ARG", "TAH", "FIJ"]

weeks = list(range(1, 10))

# %%
#matrix given
matrix = {
    "CAN": {"ICE": 49,  "SWE": 938, "RUS": 1009, "DEN": 710, "JAP": 842, "ANT": 1013, "AUS": 776, "CHI": 1612, "ARG": 1148, "TAH": 1393, "FIJ": 1345},
    "ICE": {"SWE": 981, "RUS": 1050, "DEN": 753, "JAP": 885, "ANT": 1056, "AUS": 819, "CHI": 1655, "ARG": 1192, "TAH": 1927, "FIJ": 1389},
    "SWE": {"RUS": 308, "DEN": 330, "JAP": 97, "ANT": 597, "AUS": 563, "CHI": 1074, "ARG": 897, "TAH": 1416, "FIJ": 1055},
    "RUS": {"DEN": 529, "JAP": 370, "ANT": 833, "AUS": 762, "CHI": 1302, "ARG": 1117, "TAH": 1636, "FIJ": 1275},
    "DEN": {"JAP": 194, "ANT": 385, "AUS": 234, "CHI": 983, "ARG": 667, "TAH": 1273, "FIJ": 841},
    "JAP": {"ANT": 528, "AUS": 427, "CHI": 996, "ARG": 812, "TAH": 1331, "FIJ": 971},
    "ANT": {"AUS": 238, "CHI": 600, "ARG": 306, "TAH": 889, "FIJ": 458},
    "AUS": {"CHI": 837, "ARG": 435, "TAH": 1126, "FIJ": 633},
    "CHI": {"ARG": 542, "TAH": 344, "FIJ": 388},
    "ARG": {"TAH": 736, "FIJ": 199},
    "TAH": {"FIJ": 551},
}

# %%
#distance dictionary
dist = {}
for i in teams:
    for j in teams:
        if i == j:
            dist[(i, j)] = 0
        else:
            d = None
            if i in matrix and j in matrix[i]:
                d = matrix[i][j]
            elif j in matrix and i in matrix[j]:
                d = matrix[j][i]
            if d is None:
                raise ValueError(f"Missing distance between {i} and {j}")
            dist[(i, j)] = d

# %%
print(dist)
# Out:
# {('CAN', 'CAN'): 0, ('CAN', 'ICE'): 49, ('CAN', 'SWE'): 938, ('CAN', 'RUS'): 1009, ('CAN', 'DEN'): 710, ('CAN', 'JAP'): 842, ('CAN', 'ANT'): 1013, ('CAN', 'AUS'): 776, ('CAN', 'CHI'): 1612, ('CAN', 'ARG'): 1148, ('CAN', 'TAH'): 1393, ('CAN', 'FIJ'): 1345, ('ICE', 'CAN'): 49, ('ICE', 'ICE'): 0, ('ICE', 'SWE'): 981, ('ICE', 'RUS'): 1050, ('ICE', 'DEN'): 753, ('ICE', 'JAP'): 885, ('ICE', 'ANT'): 1056, ('ICE', 'AUS'): 819, ('ICE', 'CHI'): 1655, ('ICE', 'ARG'): 1192, ('ICE', 'TAH'): 1927, ('ICE', 'FIJ'): 1389, ('SWE', 'CAN'): 938, ('SWE', 'ICE'): 981, ('SWE', 'SWE'): 0, ('SWE', 'RUS'): 308, ('SWE', 'DEN'): 330, ('SWE', 'JAP'): 97, ('SWE', 'ANT'): 597, ('SWE', 'AUS'): 563, ('SWE', 'CHI'): 1074, ('SWE', 'ARG'): 897, ('SWE', 'TAH'): 1416, ('SWE', 'FIJ'): 1055, ('RUS', 'CAN'): 1009, ('RUS', 'ICE'): 1050, ('RUS', 'SWE'): 308, ('RUS', 'RUS'): 0, ('RUS', 'DEN'): 529, ('RUS', 'JAP'): 370, ('RUS', 'ANT'): 833, ('RUS', 'AUS'): 762, ('RUS', 'CHI'): 1302, ('RUS', 'ARG'): 1117, ('RUS', 'TAH'): 1636, ('RUS', 'FIJ'): 1275, ('DEN', 'CAN'): 710, ('DEN', 'ICE'): 753, ('DEN', 'SWE'): 330, ('DEN', 'RUS'): 529, ('DEN', 'DEN'): 0, ('DEN', 'JAP'): 194, ('DEN', 'ANT'): 385, ('DEN', 'AUS'): 234, ('DEN', 'CHI'): 983, ('DEN', 'ARG'): 667, ('DEN', 'TAH'): 1273, ('DEN', 'FIJ'): 841, ('JAP', 'CAN'): 842, ('JAP', 'ICE'): 885, ('JAP', 'SWE'): 97, ('JAP', 'RUS'): 370, ('JAP', 'DEN'): 194, ('JAP', 'JAP'): 0, ('JAP', 'ANT'): 528, ('JAP', 'AUS'): 427, ('JAP', 'CHI'): 996, ('JAP', 'ARG'): 812, ('JAP', 'TAH'): 1331, ('JAP', 'FIJ'): 971, ('ANT', 'CAN'): 1013, ('ANT', 'ICE'): 1056, ('ANT', 'SWE'): 597, ('ANT', 'RUS'): 833, ('ANT', 'DEN'): 385, ('ANT', 'JAP'): 528, ('ANT', 'ANT'): 0, ('ANT', 'AUS'): 238, ('ANT', 'CHI'): 600, ('ANT', 'ARG'): 306, ('ANT', 'TAH'): 889, ('ANT', 'FIJ'): 458, ('AUS', 'CAN'): 776, ('AUS', 'ICE'): 819, ('AUS', 'SWE'): 563, ('AUS', 'RUS'): 762, ('AUS', 'DEN'): 234, ('AUS', 'JAP'): 427, ('AUS', 'ANT'): 238, ('AUS', 'AUS'): 0, ('AUS', 'CHI'): 837, ('AUS', 'ARG'): 435, ('AUS', 'TAH'): 1126, ('AUS', 'FIJ'): 633, ('CHI', 'CAN'): 1612, ('CHI', 'ICE'): 1655, ('CHI', 'SWE'): 1074, ('CHI', 'RUS'): 1302, ('CHI', 'DEN'): 983, ('CHI', 'JAP'): 996, ('CHI', 'ANT'): 600, ('CHI', 'AUS'): 837, ('CHI', 'CHI'): 0, ('CHI', 'ARG'): 542, ('CHI', 'TAH'): 344, ('CHI', 'FIJ'): 388, ('ARG', 'CAN'): 1148, ('ARG', 'ICE'): 1192, ('ARG', 'SWE'): 897, ('ARG', 'RUS'): 1117, ('ARG', 'DEN'): 667, ('ARG', 'JAP'): 812, ('ARG', 'ANT'): 306, ('ARG', 'AUS'): 435, ('ARG', 'CHI'): 542, ('ARG', 'ARG'): 0, ('ARG', 'TAH'): 736, ('ARG', 'FIJ'): 199, ('TAH', 'CAN'): 1393, ('TAH', 'ICE'): 1927, ('TAH', 'SWE'): 1416, ('TAH', 'RUS'): 1636, ('TAH', 'DEN'): 1273, ('TAH', 'JAP'): 1331, ('TAH', 'ANT'): 889, ('TAH', 'AUS'): 1126, ('TAH', 'CHI'): 344, ('TAH', 'ARG'): 736, ('TAH', 'TAH'): 0, ('TAH', 'FIJ'): 551, ('FIJ', 'CAN'): 1345, ('FIJ', 'ICE'): 1389, ('FIJ', 'SWE'): 1055, ('FIJ', 'RUS'): 1275, ('FIJ', 'DEN'): 841, ('FIJ', 'JAP'): 971, ('FIJ', 'ANT'): 458, ('FIJ', 'AUS'): 633, ('FIJ', 'CHI'): 388, ('FIJ', 'ARG'): 199, ('FIJ', 'TAH'): 551, ('FIJ', 'FIJ'): 0}

# %%
for (i, j), d in dist.items():
    print((i, j), d)

# %%
tv_pairs = [("TAH", "FIJ"),
            ("SWE", "DEN"),
            ("CHI", "ARG"),
            ("ANT", "AUS")]

# %%
m = Model("sport_scheduling_WSL")

x_index = [(i, j, w) for i in teams for j in teams if i != j for w in weeks]
x = m.addVars(x_index, vtype=GRB.BINARY, name="x")

r_index = [(i, w) for i in teams for w in weeks[:-1]]
r = m.addVars(r_index, vtype=GRB.BINARY, name="r")

T_max = m.addVar(lb=0.0, name="T_max")
T_min = m.addVar(lb=0.0, name="T_min")

# %%
#Constrains

#1. one game per week, atmost
for i in teams:
    for w in weeks:
        m.addConstr(quicksum(x[i, j, w] for j in teams if j != i) +
                    quicksum(x[j, i, w] for j in teams if j != i) <= 1, name=f"one_game_{i}_{w}")

# %%
#2. same division play once with all
#North
for idx_i in range(len(north)):
    for idx_j in range(idx_i + 1, len(north)):
        i, j = north[idx_i], north[idx_j]
        m.addConstr(quicksum(x[i, j, w] + x[j, i, w] for w in weeks) == 1, name=f"division_game_N_{i}_{j}")

#South
for idx_i in range(len(south)):
    for idx_j in range(idx_i + 1, len(south)):
        i, j = south[idx_i], south[idx_j]
        m.addConstr(quicksum(x[i, j, w] + x[j, i, w] for w in weeks) == 1, name=f"division_game_S_{i}_{j}")

# %%
#3 cross division play any three
#atmost one
for i in north:  #change
    for j in south:
        m.addConstr(quicksum(x[i, j, w] + x[j, i, w] for w in weeks) <= 1, name=f"cross_division_pair_{i}_{j}")

#play three random
for i in teams:
    other_div = south if i in north else north
    m.addConstr(quicksum(x[i, j, w] + x[j, i, w] for j in other_div for w in weeks) == 3, name=f"cross_division_count_{i}")

# %%
#4 home 4 games and 4 away games for each team
for i in teams:
    home_games = quicksum(x[i, j, w] for j in teams if j != i for w in weeks)
    away_games = quicksum(x[j, i, w] for j in teams if j != i for w in weeks)
    m.addConstr(home_games == 4, name=f"home_game_count_{i}")
    m.addConstr(away_games == 4, name=f"away_game_count_{i}")

# %%
#5 back to back away not more than once and no start as well as no end with back to back away
for i in teams:
    for w in weeks[:-1]:
        away_w = quicksum(x[j, i, w] for j in teams if j != i)
        away_wplus1 = quicksum(x[j, i, w + 1] for j in teams if j != i)  #changed to w+1
        m.addConstr(r[i, w] >= away_w + away_wplus1 - 1, name=f"back2back_link_{i}_{w}")

    m.addConstr(quicksum(r[i, w] for w in weeks[:-1]) <= 1, name=f"back2back_limit_{i}")

    away_1 = quicksum(x[j, i, 1] for j in teams if j != i)
    away_2 = quicksum(x[j, i, 2] for j in teams if j != i)
    away_8 = quicksum(x[j, i, 8] for j in teams if j != i)
    away_9 = quicksum(x[j, i, 9] for j in teams if j != i)

    m.addConstr(away_1 + away_2 <= 1, name=f"start_not_back2back_{i}")
    m.addConstr(away_8 + away_9 <= 1, name=f"end_not_back2bacak_{i}")

# %%
#6 TV games
for (a, b) in tv_pairs:
    m.addConstr(quicksum(x[a, b, w] + x[b, a, w] for w in weeks) == 1, name=f"tv_once_{a}_{b}")

for w in weeks:
    m.addConstr(quicksum(x[a, b, w] + x[b, a, w] for (a, b) in tv_pairs) <= 1, name=f"tv_one_per_week_{w}")

# %%
#7 travel friendly
travel = {}
for i in teams:
    travel[i] = quicksum(dist[(j, i)] * x[j, i, w] for j in teams if j != i for w in weeks)

for i in teams:
    m.addConstr(T_max >= travel[i], name=f"Tmax_{i}")
    m.addConstr(T_min <= travel[i], name=f"Tmin_{i}")

total_travel = quicksum(travel[i] for i in teams)

# %%
lambda_fair = 0.01
lambda_b2b = 10.0

obj = total_travel + lambda_fair * (T_max - T_min) + lambda_b2b * quicksum(r[i, w] for (i, w) in r_index)

# %%
m.setObjective(obj, GRB.MINIMIZE)

# %%
m.optimize()

if m.Status not in [GRB.OPTIMAL, GRB.INTERRUPTED, GRB.TIME_LIMIT]:
    print(f"Model ended with status {m.Status}")
else:
    print(f"Objective value (weighted): {m.ObjVal:.2f}")
    print("Total travel per team:")
    for i in teams:
        print(f"  {i}: {travel[i].getValue():.1f} miles")

    with open("schedule_WSL.txt", "w") as f:
        for w in weeks:
            for i in teams:
                for j in teams:
                    if i == j:
                        continue
                    if x[i, j, w].X > 0.5:
                        # Line format: HOME AWAY WEEK
                        f.write(f"{i} {j} {w}\n")

    print("Schedule written to schedule_WSL.txt")
# Out:
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 379 rows, 1286 columns and 12612 nonzeros (Min)
# Model fingerprint: 0xe3d2f42d
# Model has 1286 linear objective coefficients
# Variable types: 2 continuous, 1284 integer (1284 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e-02, 2e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+00]
# Presolve removed 28 rows and 24 columns
# Presolve time: 0.03s
# Presolved: 351 rows, 1262 columns, 11748 nonzeros
# Variable types: 0 continuous, 1262 integer (1260 binary)
#
# Root relaxation: objective 3.513017e+04, 1281 iterations, 0.08 seconds (0.05 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 35130.1686    0  175          - 35130.1686      -     -    0s
#      0     0 35131.8245    0  169          - 35131.8245      -     -    0s
#      0     0 35132.0148    0  175          - 35132.0148      -     -    0s
#      0     0 35132.0148    0  163          - 35132.0148      -     -    0s
#      0     0 35132.0148    0  163          - 35132.0148      -     -    0s
#      0     0 35132.0148    0  163          - 35132.0148      -     -    0s
# H    0     0                    36841.530000 35132.0148  4.64%     -    1s
# H    0     0                    35809.560000 35132.0148  1.89%     -    1s
#      0     2 35132.0148    0  154 35809.5600 35132.0148  1.89%     -    2s
# H    4     4                    35554.200000 35132.0148  1.19%   179    2s
# H    4     4                    35553.940000 35132.0148  1.19%   179    2s
# H    8     8                    35271.940000 35132.0148  0.40%   192    2s
# H    8     8                    35270.680000 35132.0148  0.39%   192    3s
#     55    57 35132.0553   42  146 35270.6800 35132.0148  0.39%   192    5s
# H  148   148                    35247.490000 35132.0148  0.33%   216    8s
# H  148   148                    35246.820000 35132.0148  0.33%   216    8s
# H  245   237                    35236.820000 35132.0148  0.30%   162    8s
# H  245   237                    35229.760000 35132.0148  0.28%   162    8s
# H  245   237                    35228.900000 35132.0148  0.28%   162    8s
#    296   290 35136.6918   51  123 35228.9000 35132.0148  0.28%   172   10s
# H  450   432                    35218.900000 35132.0148  0.25%   148   10s
# H  450   432                    35208.900000 35132.0148  0.22%   148   11s
# H  450   432                    35207.690000 35132.0148  0.21%   148   11s
# H  534   487                    35206.960000 35132.0760  0.21%   163   14s
# H  534   462                    35205.540000 35132.0760  0.21%   163   14s
#    551   475 35132.1235   21  157 35205.5400 35132.0760  0.21%   169   15s
# H  618   495                    35203.550000 35132.0760  0.20%   178   17s
#    696   549 35143.9780   93  115 35203.5500 35132.0760  0.20%   186   20s
# H  732   549                    35203.040000 35132.0760  0.20%   185   21s
# H  732   528                    35196.600000 35132.0760  0.18%   185   21s
# H  789   522                    35147.850000 35132.0760  0.04%   182   22s
#    882   571 35132.0891   56  145 35147.8500 35132.0760  0.04%   189   25s
# H 1005   605                    35143.720000 35132.0760  0.03%   206   28s
# H 1005   586                    35143.640000 35132.0760  0.03%   206   28s
#   1121   607 35133.1837   25  144 35143.6400 35132.0760  0.03%   203   30s
# H 1254   643                    35143.630000 35132.0760  0.03%   200   32s
# H 1254   565                    35139.090000 35132.0760  0.02%   200   33s
#   1371   645 35134.4044   76  120 35139.0900 35132.0760  0.02%   203   35s
#   1595   795 35132.4370   53  125 35139.0900 35132.0760  0.02%   205   41s
#   1793   945 35132.0860   59  148 35139.0900 35132.0760  0.02%   206   45s
#   2017  1118 35134.1561   71   99 35139.0900 35132.0760  0.02%   205   50s
#   2577  1565 35132.0760   28  175 35139.0900 35132.0760  0.02%   187   55s
#   2965  1888 35132.0773   23  173 35139.0900 35132.0760  0.02%   181   60s
#   3451  2327 35132.5198  114  143 35139.0900 35132.0760  0.02%   177   65s
# H 3777  2558                    35137.600000 35132.0760  0.02%   174   69s
#   3813  2596 35132.6533   46  141 35137.6000 35132.0760  0.02%   176   70s
#   4307  3013 35133.9781   44  143 35137.6000 35132.0760  0.02%   173   75s
# H 4555  3062                    35136.300000 35132.0760  0.01%   172   79s
#   4583  3065 35132.0760   33  176 35136.3000 35132.0760  0.01%   172   80s
#   4824  3236 35133.3200   53  137 35136.3000 35132.0760  0.01%   174   85s
#   5116  3484 35133.6169   40  158 35136.3000 35132.0951  0.01%   172   90s
#   5282  3573 35133.3200  102  130 35136.3000 35132.0960  0.01%   180   95s
#   5491  3666 35132.6282   82  160 35136.3000 35132.0973  0.01%   186  100s
# H 5689  3575                    35135.500000 35132.0973  0.01%   189  105s
#
# Cutting planes:
#   Gomory: 7
#   Clique: 13
#
# Explored 5690 nodes (1079210 simplex iterations) in 106.01 seconds (74.49 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 10: 35135.5 35136.3 35137.6 ... 35203
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.513550000000e+04, best bound 3.513209725819e+04, gap 0.0097%
# Objective value (weighted): 35135.50
# Total travel per team:
#   CAN: 3565.0 miles
#   ICE: 2734.0 miles
#   SWE: 3128.0 miles
#   RUS: 3224.0 miles
#   DEN: 2515.0 miles
#   JAP: 2618.0 miles
#   ANT: 2557.0 miles
#   AUS: 2632.0 miles
#   CHI: 2832.0 miles
#   ARG: 2845.0 miles
#   TAH: 3024.0 miles
#   FIJ: 3451.0 miles
# Schedule written to schedule_WSL.txt
